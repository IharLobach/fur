# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 7.5]
plt.rcParams.update({'font.size': 16,'legend.fontsize':16})
import fur.path_assistant as path_assistant
shift = path_assistant.PathAssistant('shift_03_16_2020',
    ignore_files=['RefCurve_2020-03-16_0_084020_test.Wfm.bin',
                  'RefCurve_2020-03-16_153_155200.Wfm.bin'])

# %%
acnet_df = shift.get_acnet_data_df('all_acnet_data_with_bunch_sizes_ROUND_LONG_case_03_16_2020.csv')
acnet_df = acnet_df.loc[:,['N:IBEAMA', 'N:IRFEPA', 'N:IWCMBR', 'N:IWCMBG', 'N:IWCMBF']]

# %%
import plotly.express as px
fig = px.scatter(x=acnet_df.index, y=acnet_df['N:IRFEPA'])
fig.add_scatter(x=acnet_df.index, y=5*acnet_df['N:IWCMBF'], mode='lines')
fig.data[0].update(mode='markers+lines')
fig.data[1].update(mode='markers+lines')
fig.show()
# Out:
# <div>
#
#
#             <div id="8898ea2a-ad13-42b3-806f-0520bc2a76a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8898ea2a-ad13-42b3-806f-0520bc2a76a4")) {
#                     Plotly.newPlot(
#                         '8898ea2a-ad13-42b3-806f-0520bc2a76a4',
# ...
