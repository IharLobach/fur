# %%
from fur.path_assistant import get_plot_style_sheet
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.use("pgf")
plt.style.use(get_plot_style_sheet("prab"))
plt.plot([1, 2, 3])
plt.xlabel(r'Photoelectron count variance $\mathrm{var}(\mathcal{N})$, $\epsilon_x$, (\SI{}{nm})')
plt.ylabel(r'Normal text ...')
# Out:
# Text(0, 0.5, 'Normal text ...')
