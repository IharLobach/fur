# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# size = 10
# ys = np.random.uniform(high=3,size=size)
# xs = np.random.uniform(high=400, size=size)

# %%
xs = np.array([213.64569986,  53.46581631, 249.74240291, 339.40094354,
        23.78933151, 104.26781227, 114.74633031, 159.82332467,
       266.94269563, 385.01371139])

# %%
ys = np.array([1.12311698, 1.08703837, 0.76256673, 0.24534496, 1.13523631,
       1.47376454, 1.39543571, 1.78265267, 2.33182985, 2.84637696])

# %%
s = 7
per = 4
x0 = np.linspace(-20,20,500)
y0 = np.exp(-x0**2/2/s**2)*np.sin(2*np.pi*x0/per)
fig, ax = plt.subplots(figsize=[15,3.5])
plt.axis('off')
for x,y in zip(xs,ys):
    ax.plot(x+x0,y0, color='b')
