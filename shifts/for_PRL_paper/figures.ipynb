# %%
import os
import fur.path_assistant as pa
import figure_arrange_scripts as ff

# %%
source_figures_path = os.path.join(pa.get_from_config("data_folder"),
             "fur_publications",
             "PRL_experimental",
             "source_figures")

# %%
im_paths = [os.path.join(source_figures_path, p) for p in 
            ["integrating_circuit.png",
             "comb_filter.png"]
           ]
output_path = pa.get_PRL_images_dir().fi("integrator_and_comb_filter.png")

# %%
ff.RowOfFigures(im_paths,output_path, fontsize=100)
# Out:
# ...
# Result saved to /home/ilobach/FUR_Run2_experiment_paper/images/integrator_and_comb_filter.png
# <PIL.Image.Image image mode=RGB size=2866x889 at 0x7F2360421358>
