# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
E1 = 1.4e3
lam1 = 1240/E1*1e-9
sx = 325e-6
sy = 86e-6
sxp = 30e-6
syp = 21.2e-6
Mx = sx*sxp/(lam1/4/np.pi)
My = sy*syp/(lam1/4/np.pi)
sz = 5.3e-3
Nu = 28
skrel = 0.1/Nu
sk = skrel*2*np.pi/lam1
Ml = 2*sk*sz
M = Ml*Mx*My
Ne = 1.2e11
avN = np.pi/2*1/137*Nu*Ne*skrel*np.sqrt(2*np.pi)
Mx, My, Ml, M, avN
# Out:
# (138.33141845645378,
#  25.867265859467338,
#  268555.5010326759,
#  960960219.5540435,
#  344881969.61435956)

# %%
lam1
# Out:
# 8.857142857142858e-10
