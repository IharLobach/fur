# %%
import numpy as np
import scipy.signal
from scipy.optimize import minimize
from datetime import datetime
from fur.one_data_set_analyzer import analyze_one_dataset
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from datetime import datetime
plt.rcParams['figure.figsize'] = [15, 7.5]
plt.rcParams.update({'font.size': 16,'legend.fontsize':16})
import seaborn as sns
import sys
import os
import fur.path_assistant as path_assistant
from fur.waveform_reader import read_waveform
from fur.finding_period import get_period
from fur.fluctuations import get_fluctiation_and_noise_var
shift_04_29_2019 = path_assistant.PathAssistant('shift_04_29_2019')
waveforms_dir = shift_04_29_2019.get_waveforms_dir()
results_dir = shift_04_29_2019.get_results_dir()

# %%
base_name = "test_light_source_04_29_2019"
res_df = analyze_one_dataset(
    shift_04_29_2019,
    base_name,
    csv=True,
    nbins=2660,
    nrows=2665*200,
    filter_window_length=51, filter_polyorder=3,
    resampling_factor=10)
# Out:
# There are 53 files in this data set.
# Started working on the file  RefCurve_2019-04-29_0_171757.Wfm.csv (1/53)
# period = 2660.0118114461993
# Sum amplitude = 0.689 V
# Finished working on  RefCurve_2019-04-29_0_171757.Wfm.csv (1/53)
# Started working on the file  RefCurve_2019-04-29_10_174911.Wfm.csv (2/53)
# period = 2660.004920342712
# Sum amplitude = 0.147 V
# Finished working on  RefCurve_2019-04-29_10_174911.Wfm.csv (2/53)
# Started working on the file  RefCurve_2019-04-29_11_175226.Wfm.csv (3/53)
# period = 2660.004700849019
# Sum amplitude = 0.0603 V
# Finished working on  RefCurve_2019-04-29_11_175226.Wfm.csv (3/53)
# Started working on the file  RefCurve_2019-04-29_12_175539.Wfm.csv (4/53)
# period = 2660.002696881154
# Sum amplitude = 0.0589 V
# Finished working on  RefCurve_2019-04-29_12_175539.Wfm.csv (4/53)
# Started working on the file  RefCurve_2019-04-29_13_175756.Wfm.csv (5/53)
# period = 2660.005329652813
# Sum amplitude = 0.0594 V
# ...
