# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 7.5]
import scipy as sp
import math
import scipy.optimize as optimize
from statistics import mean
import random
import itertools
from itertools import islice
from scipy.signal import find_peaks
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import pickle
from itertools import zip_longest
from decimal import Decimal
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from scipy import optimize
import scipy
import os.path as path

def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)
def column(matrix, i):
    return [row[i] for row in matrix]
def least_squares(X,Y):
    XY = [i*j for i,j in zip(X,Y)]
    X2 = [i**2 for i in X]
    meanX = mean(X)
    meanY=mean(Y)
    a = (mean(XY)-meanX*meanY)/(mean(X2)-meanX**2)
    b = meanY-a*meanX
    a_error = math.sqrt(np.var([a*i-j for i,j in zip(X,Y)])/sum([(x-meanX)**2 for x in X]))
    return [a,b,a_error]
import numpy as np
from scipy.signal import butter, lfilter, freqz
import matplotlib.pyplot as plt
from scipy import signal


def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 7.5]
plt.rcParams.update({'font.size': 28,'legend.fontsize':22})
import scipy as sp
import math
import scipy.optimize as optimize
from statistics import mean
import random
import itertools
from itertools import islice
from scipy.signal import find_peaks
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import pickle
from itertools import zip_longest
from decimal import Decimal
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from scipy import optimize
import scipy
import os.path as path
import matplotlib

def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)
def column(matrix, i):
    return [row[i] for row in matrix]
def least_squares(X,Y):
    XY = [i*j for i,j in zip(X,Y)]
    X2 = [i**2 for i in X]
    meanX = mean(X)
    meanY=mean(Y)
    a = (mean(XY)-meanX*meanY)/(mean(X2)-meanX**2)
    b = meanY-a*meanX
    a_error = math.sqrt(np.var([a*i-j for i,j in zip(X,Y)])/sum([(x-meanX)**2 for x in X]))
    return [a,b,a_error]

def least_squares_0(X,Y):
    XY = [i*j for i,j in zip(X,Y)]
    X2 = [i**2 for i in X]
    meanX = mean(X)
    meanY=mean(Y)
    return mean(XY)/mean(X2)
def least_squares_4D(X1,X2,X3,Y):
    G=np.ones((len(Y),4))
    G[:,0]=X1
    G[:,1]=X2
    G[:,2]=X3
    (a,b,c,d),resid,rank,s = np.linalg.lstsq(G,Y,rcond=None)
    return [a,b,c,d]

import operator

def correct_his(his):
    averaged_his = scipy.signal.savgol_filter(his,int(np.ceil(len(his)/10)//2*2+1),1)
    return [i-j for i,j in zip(his,averaged_his)]

import sys

plt.rcParams["text.usetex"] =True

# %%
file = "/mnt/g/My Drive/UHCICAGO/Thesis/Theory/Valeri's_idea/Experimetnal_data/3-31/directly_connected/RefCurve_2019-03-31_0_201003.Wfm.csv"

# %%
f=open(file)
ch1 = []
for i in range(500*2600):
    l=f.readline()
    ch1.append(-float(l))
f.close()

# %%
plt.rcParams.update({'font.size': 40,'legend.fontsize':22})
n0=2640
#peaks, _ = find_peaks(ch1[0:-1400], height=0, distance = 0.95*n0)
fig, ax1 = plt.subplots()
data = ch1[800:800+3*n0]
time = [0.05*t for t in range(len(data))]
plt.plot(time,data,color='tab:red')
ax1.set_xlabel('Time, ns')
ax1.set_ylabel('Integrator output, V')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
1e-6*10/3e8
# Out:
# 3.333333333333333e-14
