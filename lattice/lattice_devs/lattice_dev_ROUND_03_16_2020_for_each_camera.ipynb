# %%
import datetime
import time
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from config import get_from_config, save_to_config
from acnet_reader.acnet_reader import fetch_data, get_interpolated_df, fetch_interpolated_data
import fur.path_assistant as path_assistant
import lattice.lattice as lattice
shift_03_16_2020 = path_assistant.PathAssistant('shift_03_16_2020')
waveforms_dir = shift_03_16_2020.get_waveforms_dir()
results_dir = shift_03_16_2020.get_results_dir()
acnet_data_dir = shift_03_16_2020.get_acnet_data_dir()
bpm_data_dir = shift_03_16_2020.get_bpm_data_dir()
bpm_files_df = shift_03_16_2020.get_bpm_files_df()
acnet_data_df = shift_03_16_2020.get_acnet_data_df("all_acnet_data_for_shift_03_16_2020.csv")
from fur.extending_with_acnet_data import get_fluctuations_df_with_acnet_data
from fur.extending_with_acnet_data import get_fluctuations_df_with_acnet_data
fluctuations_df = get_fluctuations_df_with_acnet_data(
    shift_03_16_2020,
    "res_df_comb_filter_no_nd_filters_ROUND_data_03_16_2020.csv",
    "IOTA_1NL_100MeV_v8.6.1.4.6ds_data.txt"
)
from config import get_from_config
lattice_file = shift_03_16_2020.get_6dsim_dir().fi("IOTA_1NL_100MeV_v8.6.1.4.6ds_data.txt")
# Out:
# /home/ilobach/fur/env/lib/python3.6/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ilobach/fur/lattice/lattice.py:146: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(e_um*1e4*beta_cm+(1e4*dispersion_cm*dpp)**2)

# %%
lattice_df = lattice.read_lattice_file(lattice_file)
lattice_df
# Out:
#             S_cm  Dispersion_cm_X  Beta_cm_X   Beta_cm_Y       Alpha_X  \
# 0       0.000000       -24.202678  79.069986  115.457907  3.815143e-07
# 2       4.666667       -24.202678  79.345437  115.646529 -5.902559e-02
# 3       9.333333       -24.202678  80.171797  116.212393 -1.180516e-01
# 4      14.000000       -24.202678  81.549066  117.155498 -1.770775e-01
# 5      18.604167       -24.202678  83.447781  118.455670 -2.353130e-01
# ..           ...              ...        ...         ...           ...
# 928  3976.606466       -24.202678  84.129372  118.922362  2.529686e-01
# 929  3981.606466       -24.202678  81.915897  117.406657  1.897265e-01
# 930  3986.606466       -24.202678  80.334842  116.324011  1.264844e-01
# 931  3991.606466       -24.202678  79.386208  115.674423  6.324232e-02
# 932  3996.606466       -24.202678  79.069995  115.457893  2.137762e-07
#
#           Alpha_Y        dS           dDx        dDx/dS
# 0   -1.043665e-07  4.666667 -3.552714e-15 -7.612958e-16
# 2   -4.041888e-02  4.666667 -3.552714e-15 -7.612958e-16
# 3   -8.083765e-02  4.666667  0.000000e+00  0.000000e+00
# 4   -1.212564e-01  4.666667 -3.552714e-15 -7.612958e-16
# 5   -1.611339e-01  4.604167 -3.552714e-15 -7.716301e-16
# ..            ...       ...           ...           ...
# 928  1.732234e-01  5.000000 -7.105427e-15 -1.421085e-15
# 929  1.299176e-01  5.000000 -1.065814e-14 -2.131628e-15
# 930  8.661173e-02  5.000000 -1.421085e-14 -2.842171e-15
# 931  4.330589e-02  5.000000 -7.105427e-15 -1.421085e-15
# 932  6.337172e-08  5.000000 -1.065814e-14 -2.131628e-15
#
# [916 rows x 9 columns]

# %%
lattice.plot_lattice(lattice_df)

# %%
idx=1

# %%
cameras_df = lattice.get_cameras_df(
    lattice_df,
    fluctuations_df.loc[idx,lattice.acnet_devices_X].values,
    fluctuations_df.loc[idx,lattice.acnet_devices_Y].values)
cameras_df
# Out:
#   Name         S_cm  Dispersion_cm_X   Beta_cm_X   Beta_cm_Y   Alpha_X  \
# 0  M1R   312.390772         9.722311   36.225434  188.171560  0.508217
# 1  M2R   847.531424         8.867605  332.373347   30.217598  1.107789
# 2  M3R  1146.760637       149.997534  410.057483   67.853144 -1.054932
# 3  M4R  1648.557835       -49.483645  272.884031  195.416364  0.304775
# 4  M4L  2312.048374       -47.892921  200.362880  252.677345 -1.549672
# 5  M3L  2846.836442       149.983921  415.934446   71.284732  0.832799
# 6  M2L  3146.927526         9.901680  327.556295   27.031383 -1.229046
# 7  M1L  3646.794132         0.035522   40.729689  328.847554  0.616955
#
#     Alpha_Y        dS       dDx    dDx/dS ACNET_device_X ACNET_device_Y  \
# 0 -1.458162  4.891733 -2.428465 -0.496441      N:ITC1RSH      N:ITC1RSV
# 1  0.754704  4.737408  2.129491  0.449506      N:ITC2RSH      N:ITC2RSV
# 2 -0.549460  4.737408  0.220231  0.046488      N:ITC3RSH      N:ITC3RSV
# 3 -0.585537  4.702819 -1.765538 -0.375931      N:ITC4RSH      N:ITC4RSV
# 4  1.007521  4.707737 -2.210668 -0.470412      N:ITC4LSH      N:ITC4LSV
# 5  0.607294  4.737408  0.323153  0.068213      N:ITC3LSH      N:ITC3LSV
# 6 -0.642134  4.737408 -2.522276 -0.532417      N:ITC2LSH      N:ITC2LSV
# 7  2.350427  4.155523  0.035522  0.007265      N:ITC1LSH      N:ITC1LSV
#
#   Measured_sigma_um_X Measured_sigma_um_Y
# 0             198.837             447.977
# 1             586.151             179.239
# 2             765.857              270.34
# 3             732.771             105.999
# 4             470.083             529.416
# 5             787.496             269.333
# 6             628.122             179.329
# 7              201.17             547.008

# %%
active_cameras = ['M1R', 'M2R', 'M3R', 'M4L', 'M3L', 'M2L', 'M1L']
def get_e_um_Y_dict(cameras_df):
    no_m4r = cameras_df[cameras_df["Name"].isin(active_cameras)]
    ey_vals = no_m4r["Measured_sigma_um_Y"]**2/(1e4*no_m4r["Beta_cm_Y"])
    ey_dict = {}
    for cam, val in zip(no_m4r["Name"], ey_vals):
        ey_dict[cam] = val
    return ey_dict
def get_e_um_X_dict(cameras_df, dpp=0):
    no_m4r = cameras_df[cameras_df["Name"].isin(active_cameras)]
    ex_vals = (no_m4r["Measured_sigma_um_X"]**2\
               -(1e4*no_m4r["Dispersion_cm_X"]*dpp)**2)\
        /(1e4*no_m4r["Beta_cm_X"])
    ex_dict = {}
    for cam, val in zip(no_m4r["Name"], ex_vals):
        ex_dict[cam] = val
    return ex_dict

# %%
get_e_um_Y_dict(cameras_df)
# Out:
# {'M1R': 0.10664900975225292,
#  'M2R': 0.10631817527976187,
#  'M3R': 0.1077085143349381,
#  'M4L': 0.11092459512032886,
#  'M3L': 0.10176123292948354,
#  'M2L': 0.11896845619929956,
#  'M1L': 0.09098980624334724}

# %%
get_e_um_X_dict(cameras_df)
# Out:
# {'M1R': 0.10913964825968932,
#  'M2R': 0.10336959860099396,
#  'M3R': 0.14303773341745796,
#  'M4L': 0.1102889520230206,
#  'M3L': 0.1490979910721955,
#  'M2L': 0.12044868805048102,
#  'M1L': 0.09936066216726355}

# %%
ey_um_description = lattice.get_ey_um_least_squares(cameras_df, show_plot=True)

# %%
lattice.show_sigma_fit(lattice_df, cameras_df, 'Y', ey_um_description["mean"])

# %%
ey_um, ey_err = lattice.get_e_um_Y_scipy_curve_fit(cameras_df)
lattice.show_sigma_fit(lattice_df, cameras_df, 'Y', ey_um)
# Out:
# /home/ilobach/fur/env/lib/python3.6/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
ey_err/ey_um
# Out:
# 0.03527541048913697

# %%
sigma_z_cm, Vrf_V = fluctuations_df.loc[:,["N:IWCMBR", "N:IRFEPA"]].mean().values
dpp0 = lattice.get_dpp(sigma_z_cm, Vrf_V)
dpp0
# Out:
# 0.00027945715318176197

# %%
popt, perr = lattice.get_e_um_X_scipy_curve_fit(cameras_df, dpp0, 0)
ex_um, dpp = popt
ex_err, dpp_err = perr
lattice.show_sigma_fit(lattice_df, cameras_df, 'X', ex_um, dpp=dpp)
# Out:
# /home/ilobach/fur/lattice/lattice.py:148: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(e_um*1e4*beta_cm+(1e4*dispersion_cm*dpp)**2)

# %%
ex_err/ex_um
# Out:
# 0.027984099162022096

# %%
lattice.show_angle_spread_X_Y(lattice_df, ex_um, ey_um)

# %%
emmitance_6D = {
        "ex_um": ex_um,
        "ex_err_um": ex_err,
        "ey_um": ey_um,
        "ey_err_um": ey_err,
        "dp/p": dpp,
        "dp/p_err": dpp_err
    }

# %%
lattice.get_undulator_df(lattice_df, emmitance_6D)
# Out:
#            S_cm  Dispersion_cm_X   Beta_cm_X   Beta_cm_Y   Alpha_X   Alpha_Y  \
# Start   1383.90       122.936779  276.365925   65.280075  1.604628 -0.369409
# Middle  1409.65       101.204607  203.630155   98.414182  1.281779 -0.829416
# End     1435.40        79.472435  147.585260  155.330115  0.957409 -1.291591
#
#               dS       dDx    dDx/dS  Sigma_um_X  ...  Sigma_um_Y  \
# Start   4.758436 -4.015967 -0.843968  642.497828  ...  258.413852
# Middle  5.000000 -4.219839 -0.843968  545.143900  ...  317.288484
# End     5.000000 -4.219839 -0.843968  454.686283  ...  398.614690
#
#         Sigma_um_Y_err  Angle_spread_rad_X  Angle_spread_rad_Y    ex_um  \
# Start         4.557827            0.000440            0.000422  0.10666
# Middle        5.596241            0.000441            0.000419  0.10666
# End           7.030648            0.000441            0.000419  0.10666
#
#           ex_err     ey_um    ey_err      dp/p  dp/p_err
# Start   0.002985  0.102294  0.003608  0.000279       0.0
# Middle  0.002985  0.102294  0.003608  0.000279       0.0
# End     0.002985  0.102294  0.003608  0.000279       0.0
#
# [3 rows x 21 columns]

# %%
from lattice.summary_in_undulator import get_summary_in_undulator

# %%
und_summary = get_summary_in_undulator(
    lattice_file,
    fluctuations_df.loc[idx,lattice.acnet_devices_X].values,
    fluctuations_df.loc[idx,lattice.acnet_devices_Y].values,
    dpp,
    0
    )
# Out:
# /home/ilobach/fur/env/lib/python3.6/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ilobach/fur/lattice/lattice.py:148: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(e_um*1e4*beta_cm+(1e4*dispersion_cm*dpp)**2)

# %%
und_summary[0]
# Out:
#            S_cm  Dispersion_cm_X   Beta_cm_X   Beta_cm_Y   Alpha_X   Alpha_Y  \
# Start   1383.90       122.936779  276.365925   65.280075  1.604628 -0.369409
# Middle  1409.65       101.204607  203.630155   98.414182  1.281779 -0.829416
# End     1435.40        79.472435  147.585260  155.330115  0.957409 -1.291591
#
#               dS       dDx    dDx/dS  Sigma_um_X  ...  Sigma_um_Y  \
# Start   4.758436 -4.015967 -0.843968  642.497828  ...  258.413852
# Middle  5.000000 -4.219839 -0.843968  545.143900  ...  317.288484
# End     5.000000 -4.219839 -0.843968  454.686283  ...  398.614690
#
#         Sigma_um_Y_err  Angle_spread_rad_X  Angle_spread_rad_Y    ex_um  \
# Start         4.557827            0.000440            0.000422  0.10666
# Middle        5.596241            0.000441            0.000419  0.10666
# End           7.030648            0.000441            0.000419  0.10666
#
#           ex_err     ey_um    ey_err      dp/p  dp/p_err
# Start   0.002985  0.102294  0.003608  0.000279       0.0
# Middle  0.002985  0.102294  0.003608  0.000279       0.0
# End     0.002985  0.102294  0.003608  0.000279       0.0
#
# [3 rows x 21 columns]

# %% [markdown]
# # Sigma_X error can be made smaller, if I independently estimate dpp and do not fit it here.

# %%
und_summary[1]
# Out:
# {'ex_um': 0.10666039678037913,
#  'ex_err_um': 0.002984795120162752,
#  'ey_um': 0.10229418205031438,
#  'ey_err_um': 0.003608469262475346,
#  'dp/p': 0.00027945715318176197,
#  'dp/p_err': 0}

# %%
und_summary[1].values()
# Out:
# dict_values([0.10666039678037913, 0.002984795120162752, 0.10229418205031438, 0.003608469262475346, 0.00027945715318176197, 0])
